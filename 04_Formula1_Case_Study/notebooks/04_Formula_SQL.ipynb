# %% [markdown]
# ## Formula Analysis SQL
# **Note:** This notebook focuses on practicing SQL using the dataset. It contains SQL queries only. Business insights and data interpretation are documented in the Python EDA notebook.
#
# ### SQL Practice Notebook
#
# * 1. Basic SELECT Statements
# * 2. Filtering Data (WHERE)
# * 3. Sorting Results (ORDER BY)
# * 4. Aggregate Functions
# * 5. GROUP BY
# * 6. Multiple Conditions
# * 7. CASE WHEN
# * 8. HAVING
# * 9. Subqueries
# * 10. Window Functions
