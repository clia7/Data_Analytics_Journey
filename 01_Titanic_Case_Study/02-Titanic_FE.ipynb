# %% [markdown]
# # Titanic Data Analysis
# ## Feature Engineering
# - *Goal: Transform data into predictive features*

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('Titanic_Train.csv')
print('--Data Load--')
# Out:
# --Data Load--

# %%
#starting with the raw data file and checking the basics - head information
print(df.head())
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#checking the columns
print(df.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
#checking for missing values
print(df.isna().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# *Note: I will not fill the Age missing values with the median, like in the EDA file before. And I will also keep the missing value column 'Cabin' and also the two missing rows in 'Embarked'.*

# %%
#extracting the title in the name
df['Title'] = df['Name'].str.extract(' ([A-Za-z]+)\.', expand=False)
#checking the values
print(df['Title'].unique())
# Out:
# ['Mr' 'Mrs' 'Miss' 'Master' 'Don' 'Rev' 'Dr' 'Mme' 'Ms' 'Major' 'Lady'
#  'Sir' 'Mlle' 'Col' 'Capt' 'Countess' 'Jonkheer']

# %%
#replacing the french title and change it to english title
df['Title'] = df['Title'].replace('Mlle', 'Miss')
df['Title'] = df['Title'].replace('Mme', 'Mrs')
df['Title'] = df['Title'].replace('Ms', 'Miss')

#checking the 'Title' column
print(df['Title'].unique())
# Out:
# ['Mr' 'Mrs' 'Miss' 'Master' 'Don' 'Rev' 'Dr' 'Major' 'Lady' 'Sir' 'Col'
#  'Capt' 'Countess' 'Jonkheer']

# %%
#replacing some specific titles 
rare_title =['Don', 'Rev', 'Dr', 'Major', 'Lady', 'Sir', 'Col', 'Capt', 'Countess', 'Jonkheer']
df['Title'] = df['Title'].replace(rare_title, 'Rare')

#checking the 'Title' column
print(df['Title'].value_counts())
# Out:
# Title
# Mr        517
# Miss      185
# Mrs       126
# Master     40
# Rare       23
# Name: count, dtype: int64
