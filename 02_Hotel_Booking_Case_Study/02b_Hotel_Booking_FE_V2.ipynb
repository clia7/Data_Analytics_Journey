# %% [markdown]
# # Hotel Booking Demand Analysis
# ## Feature Engineering
# ## 2nd Iteration
# * **Goal:** Filling missing values and preparing Dataset for ML

# %%
# Import libraries
import pandas as pd
import numpy as np
import seaborn as sns

# Safe dataloading
file_path = 'hotel_bookings.csv'
try:
    df = pd.read_csv(file_path)
    print(f'File: {file_path} load successfully')
except FileNotFoundError:
    print(f'File not foundd - check {file_path}')
# Out:
# File: hotel_bookings.csv load successfully
